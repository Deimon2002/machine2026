# %% [markdown]
# ![logo itq](img/Recurso-26.png)
# # ITQ
# # PAO 2025-2026
# **Nombre** *Ronny Bastidas* <br>
# **Fecha**  *08/01/2026*

# %% [markdown]
# <h1>Introduccion a python</h1>

# %%
#Aqui va un comentario
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# https://github.com/Deimon2002/machine2026.git
